# %% [markdown]
# Step 1 – Install and Set Up

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 2.0 MB/s eta 0:00:07
#      --- ------------------------------------ 1.0/12.8 MB 1.7 MB/s eta 0:00:07
#      --- ------------------------------------ 1.0/12.8 MB 1.7 MB/s eta 0:00:07
#      ---- ----------------------------------- 1.6/12.8 MB 1.5 MB/s eta 0:00:08
#      ----- ---------------------------------- 1.8/12.8 MB 1.5 MB/s eta 0:00:08
#      ----- ---------------------------------- 1.8/12.8 MB 1.5 MB/s eta 0:00:08
#      ------ --------------------------------- 2.1/12.8 MB 1.2 MB/s eta 0:00:09
#      ------- -------------------------------- 2.4/12.8 MB 1.2 MB/s eta 0:00:09
# ...

# %% [markdown]
# load the model

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
with open("C:/Users/ajmel/Desktop/NLP-LLM-Learning-Journey/Week 1  — NLP Foundations + Embeddings/datasets/et.txt", "r") as f:
    text = f.read()

# %%
print(text)
# Out:
# Ethiopia, located in the Horn of Africa, is one of the oldest nations in the world with a history that dates back thousands of years.
# It is known for being the only African country that was never colonized, maintaining its sovereignty throughout the Scramble for Africa.
# The country is home to ancient civilizations such as the Kingdom of Aksum, which was a major trading empire and one of the earliest adopters of Christianity.
#
# The capital city, Addis Ababa, serves as both the political and cultural heart of Ethiopia.
# It hosts the headquarters of the African Union and numerous international organizations.
# The city is a vibrant mix of tradition and modernity, with bustling markets, historic churches, and a growing tech scene.
# Ethiopiaâ€™s diverse population speaks over 80 languages, including Amharic, Oromo, and Tigrinya, reflecting its rich cultural mosaic.
#
# Ethiopiaâ€™s economy is largely based on agriculture, with coffee being one of its most famous exports.
# ...

# %%
doc = nlp(text)

# %%
print(doc)
# Out:
# Ethiopia, located in the Horn of Africa, is one of the oldest nations in the world with a history that dates back thousands of years.
# It is known for being the only African country that was never colonized, maintaining its sovereignty throughout the Scramble for Africa.
# The country is home to ancient civilizations such as the Kingdom of Aksum, which was a major trading empire and one of the earliest adopters of Christianity.
#
# The capital city, Addis Ababa, serves as both the political and cultural heart of Ethiopia.
# It hosts the headquarters of the African Union and numerous international organizations.
# The city is a vibrant mix of tradition and modernity, with bustling markets, historic churches, and a growing tech scene.
# Ethiopiaâ€™s diverse population speaks over 80 languages, including Amharic, Oromo, and Tigrinya, reflecting its rich cultural mosaic.
#
# Ethiopiaâ€™s economy is largely based on agriculture, with coffee being one of its most famous exports.
# ...

# %%
print(len(text))
print(len(doc))
# Out:
# 1313
# 244

# %%
for token in text[:10]:
    print(token)
# Out:
# E
# t
# h
# i
# o
# p
# i
# a
# ,

# %%
for token in doc[:10]:
    print(token)
# Out:
# Ethiopia
# ,
# located
# in
# the
# Horn
# of
# Africa
# ,
# is

# %%
for token in text.split()[:10]:
    print(token)
# Out:
# Ethiopia,
# located
# in
# the
# Horn
# of
# Africa,
# is
# one
# of

# %% [markdown]
# Sentence Boundary Detection

# %%
for sent in doc.sents:
    print(sent)
# Out:
# Ethiopia, located in the Horn of Africa, is one of the oldest nations in the world with a history that dates back thousands of years.
#
# It is known for being the only African country that was never colonized, maintaining its sovereignty throughout the Scramble for Africa.
#
# The country is home to ancient civilizations such as the Kingdom of Aksum, which was a major trading empire and one of the earliest adopters of Christianity.
#
#
# The capital city, Addis Ababa, serves as both the political and cultural heart of Ethiopia.
#
# It hosts the headquarters of the African Union and numerous international organizations.
#
# The city is a vibrant mix of tradition and modernity, with bustling markets, historic churches, and a growing tech scene.
#
# Ethiopiaâ€™s diverse population speaks over 80 languages, including Amharic, Oromo, and Tigrinya, reflecting its rich cultural mosaic.
#
#
# ...

# %%
sent1 = list(doc.sents)[0]
print(sent1)
# Out:
# Ethiopia, located in the Horn of Africa, is one of the oldest nations in the world with a history that dates back thousands of years.

# %%
for token in doc[:10]:
    print(token)
# Out:
# Ethiopia
# ,
# located
# in
# the
# Horn
# of
# Africa
# ,
# is

# %% [markdown]
# Token attributte

# %%
toke2 = sent1[7]
print(toke2)
# Out:
# Africa

# %%
toke2.text
# Out:
# 'Africa'

# %%
toke2.left_edge
# Out:
# Africa

# %%
toke2.right_edge
# Out:
# Africa

# %%
toke2.ent_type
# Out:
# 385

# %%
toke2.ent_type_
# Out:
# 'LOC'

# %%
toke2.ent_iob_
# Out:
# 'I'

# %%
toke2.lemma_
# Out:
# 'Africa'

# %%
sent1[2].lemma_
# Out:
# 'locate'

# %%
toke2.morph
# Out:
# Number=Sing

# %%
sent1[2].morph
# Out:
# Aspect=Perf|Tense=Past|VerbForm=Part

# %%
toke2.pos_
# Out:
# 'PROPN'

# %%
toke2.dep_
# Out:
# 'pobj'

# %%
toke2.lang_
# Out:
# 'en'

# %% [markdown]
# POS

# %%
text = "messi enjoys playing football"
docs2 = nlp(text)
for token in docs2:
    print(token.text,token.pos_, token.dep_)
# Out:
# messi PROPN nsubj
# enjoys VERB ROOT
# playing VERB xcomp
# football NOUN dobj

# %%
from spacy import displacy
displacy.render(docs2, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="83b185bf0df74f338cfc9aebd27f3d31-0" class="displacy" width="750" height="224.5" direction="ltr" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">messi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">enjoys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
# ...

# %% [markdown]
# NER

# %%
for enti in doc.ents:
    print(enti.text, enti.label_)
# Out:
# Ethiopia GPE
# the Horn of Africa LOC
# thousands of years DATE
# African NORP
# Scramble PERSON
# Africa LOC
# the Kingdom of Aksum GPE
# one CARDINAL
# Christianity NORP
# Addis Ababa GPE
# Ethiopia GPE
# the African Union ORG
# 80 CARDINAL
# Amharic ORG
# Oromo ORG
# Tigrinya GPE
# mosaic PRODUCT
# recent years DATE
# Ethiopia GPE
# East Africa GPE

# %%
displacy.render(doc, style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethiopia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , located in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Horn of Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , is one of the oldest nations in the world with a history that dates back
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thousands of years
# ...

# %%
# Displaying part of speech and dependency parsing
for token in doc:
    print(token.text,token.lemma_, token.pos_,token.tag_,  token.dep_, token.shape_, token.is_alpha, token.is_stop)
# Out:
# john john PROPN NNP nsubj xxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# for for ADP IN prep xxx True True
# a a DET DT det x True True
# job job NOUN NN pobj xxx True False
# in in ADP IN prep xx True True
# the the DET DT det xxx True True
# Field Field PROPN NNP pobj Xxxxx True False
# of of ADP IN prep xx True True
# Artificial Artificial PROPN NNP compound Xxxxx True False
# Intelligence Intelligence PROPN NNP nmod Xxxxx True False
# and and CCONJ CC cc xxx True True
# Machine Machine PROPN NNP compound Xxxxx True False
# Learning Learning PROPN NNP conj Xxxxx True False
# and and CCONJ CC cc xxx True True
# Data Data PROPN NNP conj Xxxx True False
# Science Science PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False

# %% [markdown]
# NER

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# john 0 4 PERSON
# the Field of Artificial Intelligence 29 65 FAC

# %% [markdown]
# Accessing Entites annotations and label

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc1 = nlp("San Francisco considers banning sidewalk delivery robots")

# document level
entite = [(e.text, e.start_char, e.end_char, e.label_) for e in doc1.ents]
print(entite)

# at token level

toke = [doc1[0].text,doc[0].ent_iob_, doc[0].ent_type_]
print(toke)
# Out:
# [('San Francisco', 0, 13, 'GPE')]
# ['San', 'B', 'PERSON']
